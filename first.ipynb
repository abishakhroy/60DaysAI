# %%
import os
os.listdir()
# Out:
# ['tuple.py',
#  'list.py',
#  'error.py',
#  'notes.txt',
#  'abish',
#  'while.py',
#  'cflow.py',
#  'file.py',
#  'first.ipynb',
#  'Text.py',
#  '.venv',
#  'for.py',
#  'dict.py',
#  'foldertest.py',
#  'set.py',
#  'func.py']

# %%
os.mkdir("abish")

# %%
import os

os.getcwd()
# Out:
# '/Users/abishakhroykarthigeson/Desktop/PythonProgramming'

# %%
file = open("notes.txt",'a')
file.write('\nlast line added')
file.close()

# %%
file = open("notes.txt",'r')
content = file.read()


print(content)
# Out:
# content changed

# %%
file = open(notes.txt,'r')

# %%
file = open("notes.txt",'w')
file.write('content changed')
file.close()

print(content)
# Out:
# hello im Abi

# %%
a = 3
